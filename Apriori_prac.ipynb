# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install apyori

# %% [markdown]
# **Importing dataset **

# %%
dataset = pd.read_csv('dataset_group.csv',header= None)

# %%
dataset.head()
# Out:
#             0  1              2
# 0  2000-01-01  1         yogurt
# 1  2000-01-01  1           pork
# 2  2000-01-01  1  sandwich bags
# 3  2000-01-01  1     lunch meat
# 4  2000-01-01  1   all- purpose

# %%
#  dataset.drop([1],axis=1,inplace=True)

# %%
len(dataset.iloc[:,0].unique().tolist())
# Out:
# 603

# %%
date_col = dataset.iloc[:,0].drop_duplicates()

# %%
date_col = pd.DataFrame(date_col)

# %%
date_col
# Out:
#                 0
# 0      2000-01-01
# 43     2000-01-02
# 135    2000-01-03
# 159    2000-01-04
# 173    2000-01-05
# ...           ...
# 22235  2002-02-22
# 22271  2002-02-23
# 22292  2002-02-24
# 22318  2002-02-25
# 22338  2002-02-26
#
# [603 rows x 1 columns]

# %%
a = date_col.iloc[:,0]

# %%
# k = np.arange(0,603,1)
# print(k)

# %%
# date_col = date_col.set_index([pd.Index(k), a])

# %%
# pd.Index(k)

# %%
type(date_col.iloc[0,0])
# Out:
# str

# %%
date_col = pd.to_datetime(date_col.iloc[:,0])

# %%
print(date_col)
# Out:
# 0       2000-01-01
# 43      2000-01-02
# 135     2000-01-03
# 159     2000-01-04
# 173     2000-01-05
#            ...
# 22235   2002-02-22
# 22271   2002-02-23
# 22292   2002-02-24
# 22318   2002-02-25
# 22338   2002-02-26
# Name: 0, Length: 603, dtype: datetime64[ns]

# %%
 dataset.iloc[:,0].unique()
# Out:
# array(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#        '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#        '2000-01-09', '2000-01-10', '2000-01-11', '2000-01-12',
#        '2000-01-13', '2000-01-14', '2000-01-15', '2000-01-16',
#        '2000-01-17', '2000-01-18', '2000-01-19', '2000-01-20',
#        '2000-01-21', '2000-01-22', '2000-01-23', '2000-01-24',
#        '2000-01-25', '2000-01-26', '2000-01-27', '2000-01-28',
#        '2000-01-29', '2000-01-30', '2000-01-31', '2000-02-01',
#        '2000-02-02', '2000-02-03', '2000-02-04', '2000-02-05',
#        '2000-02-06', '2000-02-07', '2000-02-08', '2000-02-09',
#        '2000-02-10', '2000-02-11', '2000-02-12', '2000-02-13',
#        '2000-02-14', '2000-02-15', '2000-02-16', '2000-02-17',
#        '2000-02-18', '2000-02-19', '2000-02-20', '2000-02-21',
#        '2000-02-22', '2000-02-23', '2000-02-24', '2000-02-25',
#        '2000-02-26', '2000-02-27', '2000-02-28', '2000-03-01',
# ...

# %%
dataset_tran = dataset.T

# %%
print(dataset_tran)
# Out:
#         0           1              2      ...       22340       22341       22342
# 0  2000-01-01  2000-01-01     2000-01-01  ...  2002-02-26  2002-02-26  2002-02-26
# 1           1           1              1  ...        1139        1139        1139
# 2      yogurt        pork  sandwich bags  ...  vegetables     shampoo  vegetables
#
# [3 rows x 22343 columns]

# %%
dataset_tran.iloc[1,1]
# Out:
# 1

# %%
dataset
# Out:
#                 0     1                  2
# 0      2000-01-01     1             yogurt
# 1      2000-01-01     1               pork
# 2      2000-01-01     1      sandwich bags
# 3      2000-01-01     1         lunch meat
# 4      2000-01-01     1       all- purpose
# ...           ...   ...                ...
# 22338  2002-02-26  1139               soda
# 22339  2002-02-26  1139  laundry detergent
# 22340  2002-02-26  1139         vegetables
# 22341  2002-02-26  1139            shampoo
# 22342  2002-02-26  1139         vegetables
#
# [22343 rows x 3 columns]

# %%
# Date base modeling 

# def aprior_data(dataset):
#     basket = []
#     for date in dataset[0].unique():
#         a = [dataset[2][i] for i, j in enumerate(dataset[0]) if j == date]
#         basket.append(a)
#     return basket

# %%
def aprior_data(dataset):
    basket = []
    for id in dataset[1].unique():
        a = [dataset[2][i] for i, j in enumerate(dataset[1]) if j == id]
        basket.append(a)
    return basket

# %%
basket = aprior_data(dataset)

# %%
print(basket)
# Out:
# [['yogurt', 'pork', 'sandwich bags', 'lunch meat', 'all- purpose', 'flour', 'soda', 'butter', 'vegetables', 'beef', 'aluminum foil', 'all- purpose', 'dinner rolls', 'shampoo', 'all- purpose', 'mixes', 'soap', 'laundry detergent', 'ice cream', 'dinner rolls'], ['toilet paper', 'shampoo', 'hand soap', 'waffles', 'vegetables', 'cheeses', 'mixes', 'milk', 'sandwich bags', 'laundry detergent', 'dishwashing liquid/detergent', 'waffles', 'individual meals', 'hand soap', 'vegetables', 'individual meals', 'yogurt', 'cereals', 'shampoo', 'vegetables', 'aluminum foil', 'tortillas', 'mixes'], ['soda', 'pork', 'soap', 'ice cream', 'toilet paper', 'dinner rolls', 'hand soap', 'spaghetti sauce', 'milk', 'ketchup', 'sandwich loaves', 'poultry', 'toilet paper', 'ice cream', 'ketchup', 'vegetables', 'laundry detergent', 'spaghetti sauce', 'bagels', 'soap', 'ice cream', 'shampoo', 'lunch meat', 'cereals', 'spaghetti sauce', 'pork', 'vegetables', 'cheeses', 'eggs', 'vegetables', 'vegetables'], ['cereals
# ...

# %%
basket = pd.DataFrame(basket)

# %%
basket
# Out:
#                    0                  1              2   ...    31    32    33
# 0              yogurt               pork  sandwich bags  ...  None  None  None
# 1        toilet paper            shampoo      hand soap  ...  None  None  None
# 2                soda               pork           soap  ...  None  None  None
# 3             cereals              juice     lunch meat  ...  None  None  None
# 4     sandwich loaves              pasta      tortillas  ...  None  None  None
# ...               ...                ...            ...  ...   ...   ...   ...
# 1134            sugar               beef  sandwich bags  ...  None  None  None
# 1135       coffee/tea       dinner rolls     lunch meat  ...  None  None  None
# 1136             beef         lunch meat           eggs  ...  None  None  None
# 1137    sandwich bags            ketchup           milk  ...  None  None  None
# 1138             soda  laundry detergent     vegetables  ...  None  None  None
#
# ...

# %%
transactions = []
for i in range(0, 1139):
  transactions.append([str(basket.values[i,j]) for j in range(0, 34)])

# %%
print(transactions)

# %%
from apyori import apriori
rules = apriori(transactions = transactions, min_support = 0.2, min_confidence = 0.8, min_length = 2, max_length = 2)

# %%
from apyori import apriori
rules = apriori(transactions = transactions)

# %%
results = list(rules)

# %%
results
# Out:
# [RelationRecord(items=frozenset({'None'}), support=0.974539069359087, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'None'}), confidence=0.974539069359087, lift=1.0)]),
#  RelationRecord(items=frozenset({'all- purpose'}), support=0.3748902546093064, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'all- purpose'}), confidence=0.3748902546093064, lift=1.0)]),
#  RelationRecord(items=frozenset({'aluminum foil'}), support=0.3845478489903424, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'aluminum foil'}), confidence=0.3845478489903424, lift=1.0)]),
#  RelationRecord(items=frozenset({'bagels'}), support=0.3854258121158911, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'bagels'}), confidence=0.3854258121158911, lift=1.0)]),
# ...
